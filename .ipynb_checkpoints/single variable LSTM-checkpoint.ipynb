# %%
import pickle
import pandas as pd
import seaborn as sns

# %%
air_df = pickle.load(open("air_df_1.p",'rb'))
open('air_df_1.p','rb').close
# Out:
# <function BufferedReader.close>

# %%
air_df.sort_values(by='Date',inplace=True)
df =air_df[['Date','Daily Max 8-hour Ozone Concentration']]
df.set_index('Date',inplace=True)

# %%
import plaidml.keras
plaidml.keras.install_backend()

from pathlib import Path
import pandas as pd
import numpy as np
import pandas_profiling
# %matplotlib inline
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)

from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense, LSTM, SimpleRNN
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import model_from_json

# %%
def plot_loss(history, title):
    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title(title)
    plt.xlabel('Nb Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    val_loss = history.history['val_loss']
    min_idx = np.argmin(val_loss)
    min_val_loss = val_loss[min_idx]
    print('Minimum validation loss of {} reached at epoch {}'.format(min_val_loss, min_idx))

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# load dataset
values = df.values
# integer encode direction
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler()
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 7, 1)
# drop columns we don't want to predict
reframed.head()
# Out:
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 7    0.246377   0.347826   0.434783   0.521739   0.478261   0.391304
# 8    0.347826   0.434783   0.521739   0.478261   0.391304   0.405797
# 9    0.434783   0.521739   0.478261   0.391304   0.405797   0.260870
# 10   0.521739   0.478261   0.391304   0.405797   0.260870   0.043478
# 11   0.478261   0.391304   0.405797   0.260870   0.043478   0.014493
#
#     var1(t-1)   var1(t)
# 7    0.405797  0.260870
# 8    0.260870  0.043478
# 9    0.043478  0.014493
# 10   0.014493  0.115942
# 11   0.115942  0.202899

# %%
y = reframed.iloc[:,-1].values
X = reframed.drop(['var1(t)'], axis =1).values
# split into train and test sets

n_train_days = 3100
n_test_days=360
train_X = X[:n_train_days,:]
train_y = y[:n_train_days]

val_X= X[n_train_days:-n_test_days,]
val_y= y[n_train_days:-n_test_days]

test_X = X[-n_test_days:,:]
test_y = y[-n_test_days:]



# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape,val_X.shape, val_y.shape ,test_X.shape, test_y.shape)
# Out:
# (3100, 1, 7) (3100,) (505, 1, 7) (505,) (360, 1, 7) (360,)

# %%
simple_rnn = Sequential()
simple_rnn.add(SimpleRNN(5, input_shape=(train_X.shape[1], train_X.shape[2])))
simple_rnn.add(Dense(1))
simple_rnn.compile(loss='mae', optimizer=RMSprop())

#checkpointer = ModelCheckpoint(filepath='simple_rnn_weights.hdf5'
#                               , verbose=0
#                               , save_best_only=True)
earlystopper = EarlyStopping(monitor='val_loss'
                             , patience=30
                             , verbose=0)
with open("simple_rnn.json", "w") as m:
     m.write(simple_rnn.to_json())

simple_rnn_history = simple_rnn.fit(train_X,train_y
                                              , epochs=200
                                              , validation_data=(val_X, val_y)
                                              , verbose=2
                                              , callbacks= [earlystopper]
                                             )
plot_loss(simple_rnn_history, 'SimpleRNN - Train & Validation Loss')
# Out:
# INFO:plaidml:Opening device "opencl_amd_radeon_pro_560x_compute_engine.0"
# Train on 3100 samples, validate on 505 samples
# Epoch 1/200
#  - 0s - loss: 0.2174 - val_loss: 0.1103
# Epoch 2/200
#  - 0s - loss: 0.1106 - val_loss: 0.1013
# Epoch 3/200
#  - 0s - loss: 0.1023 - val_loss: 0.0957
# Epoch 4/200
#  - 0s - loss: 0.0962 - val_loss: 0.0884
# Epoch 5/200
#  - 0s - loss: 0.0909 - val_loss: 0.0850
# Epoch 6/200
#  - 0s - loss: 0.0869 - val_loss: 0.0803
# Epoch 7/200
#  - 0s - loss: 0.0834 - val_loss: 0.0773
# Epoch 8/200
#  - 0s - loss: 0.0806 - val_loss: 0.0751
# Epoch 9/200
#  - 0s - loss: 0.0787 - val_loss: 0.0752
# Epoch 10/200
#  - 0s - loss: 0.0765 - val_loss: 0.0716
# Epoch 11/200
#  - 0s - loss: 0.0747 - val_loss: 0.0701
# Epoch 12/200
#  - 0s - loss: 0.0730 - val_loss: 0.0723
# Epoch 13/200
#  - 0s - loss: 0.0721 - val_loss: 0.0685
# Epoch 14/200
#  - 0s - loss: 0.0711 - val_loss: 0.0725
# Epoch 15/200
#  - 0s - loss: 0.0704 - val_loss: 0.0698
# Epoch 16/200
#  - 0s - loss: 0.0699 - val_loss: 0.0733
# Epoch 17/200
#  - 0s - loss: 0.0695 - val_loss: 0.0675
# Epoch 18/200
#  - 0s - loss: 0.0690 - val_loss: 0.0654
# Epoch 19/200
#  - 0s - loss: 0.0687 - val_loss: 0.0652
# Epoch 20/200
#  - 0s - loss: 0.0684 - val_loss: 0.0655
# Epoch 21/200
#  - 0s - loss: 0.0684 - val_loss: 0.0654
# Epoch 22/200
#  - 0s - loss: 0.0681 - val_loss: 0.0668
# Epoch 23/200
#  - 0s - loss: 0.0681 - val_loss: 0.0645
# Epoch 24/200
#  - 0s - loss: 0.0680 - val_loss: 0.0643
# Epoch 25/200
#  - 0s - loss: 0.0681 - val_loss: 0.0655
# Epoch 26/200
#  - 0s - loss: 0.0678 - val_loss: 0.0642
# Epoch 27/200
#  - 0s - loss: 0.0679 - val_loss: 0.0657
# Epoch 28/200
#  - 0s - loss: 0.0677 - val_loss: 0.0643
# Epoch 29/200
#  - 0s - loss: 0.0676 - val_loss: 0.0644
# Epoch 30/200
#  - 0s - loss: 0.0677 - val_loss: 0.0652
# Epoch 31/200
#  - 0s - loss: 0.0676 - val_loss: 0.0666
# Epoch 32/200
#  - 0s - loss: 0.0676 - val_loss: 0.0651
# Epoch 33/200
#  - 0s - loss: 0.0675 - val_loss: 0.0650
# Epoch 34/200
#  - 0s - loss: 0.0676 - val_loss: 0.0640
# Epoch 35/200
#  - 0s - loss: 0.0676 - val_loss: 0.0653
# Epoch 36/200
#  - 0s - loss: 0.0675 - val_loss: 0.0640
# Epoch 37/200
#  - 0s - loss: 0.0675 - val_loss: 0.0645
# Epoch 38/200
#  - 0s - loss: 0.0675 - val_loss: 0.0641
# Epoch 39/200
#  - 0s - loss: 0.0676 - val_loss: 0.0652
# Epoch 40/200
#  - 0s - loss: 0.0674 - val_loss: 0.0638
# Epoch 41/200
#  - 0s - loss: 0.0672 - val_loss: 0.0654
# Epoch 42/200
#  - 0s - loss: 0.0673 - val_loss: 0.0646
# Epoch 43/200
#  - 0s - loss: 0.0674 - val_loss: 0.0658
# Epoch 44/200
#  - 0s - loss: 0.0674 - val_loss: 0.0646
# Epoch 45/200
#  - 0s - loss: 0.0675 - val_loss: 0.0638
# Epoch 46/200
#  - 0s - loss: 0.0675 - val_loss: 0.0648
# Epoch 47/200
#  - 0s - loss: 0.0674 - val_loss: 0.0637
# Epoch 48/200
#  - 0s - loss: 0.0673 - val_loss: 0.0639
# Epoch 49/200
#  - 0s - loss: 0.0675 - val_loss: 0.0652
# Epoch 50/200
#  - 0s - loss: 0.0676 - val_loss: 0.0637
# Epoch 51/200
#  - 0s - loss: 0.0676 - val_loss: 0.0643
# Epoch 52/200
#  - 0s - loss: 0.0674 - val_loss: 0.0654
# Epoch 53/200
#  - 0s - loss: 0.0673 - val_loss: 0.0643
# Epoch 54/200
#  - 0s - loss: 0.0672 - val_loss: 0.0658
# Epoch 55/200
#  - 0s - loss: 0.0675 - val_loss: 0.0639
# Epoch 56/200
#  - 0s - loss: 0.0673 - val_loss: 0.0646
# Epoch 57/200
#  - 0s - loss: 0.0672 - val_loss: 0.0648
# Epoch 58/200
#  - 0s - loss: 0.0674 - val_loss: 0.0657
# Epoch 59/200
#  - 0s - loss: 0.0673 - val_loss: 0.0645
# Epoch 60/200
#  - 0s - loss: 0.0673 - val_loss: 0.0637
# Epoch 61/200
#  - 0s - loss: 0.0671 - val_loss: 0.0654
# Epoch 62/200
#  - 0s - loss: 0.0674 - val_loss: 0.0638
# Epoch 63/200
#  - 0s - loss: 0.0673 - val_loss: 0.0713
# Epoch 64/200
#  - 0s - loss: 0.0673 - val_loss: 0.0662
# Epoch 65/200
#  - 0s - loss: 0.0674 - val_loss: 0.0659
# Epoch 66/200
#  - 0s - loss: 0.0675 - val_loss: 0.0663
# Epoch 67/200
#  - 0s - loss: 0.0673 - val_loss: 0.0639
# Epoch 68/200
#  - 0s - loss: 0.0674 - val_loss: 0.0640
# Epoch 69/200
#  - 0s - loss: 0.0673 - val_loss: 0.0643
# Epoch 70/200
#  - 0s - loss: 0.0672 - val_loss: 0.0636
# Epoch 71/200
#  - 0s - loss: 0.0672 - val_loss: 0.0647
# Epoch 72/200
#  - 0s - loss: 0.0671 - val_loss: 0.0638
# Epoch 73/200
#  - 0s - loss: 0.0672 - val_loss: 0.0662
# Epoch 74/200
#  - 0s - loss: 0.0674 - val_loss: 0.0640
# Epoch 75/200
#  - 0s - loss: 0.0672 - val_loss: 0.0666
# Epoch 76/200
#  - 0s - loss: 0.0673 - val_loss: 0.0641
# Epoch 77/200
#  - 0s - loss: 0.0672 - val_loss: 0.0635
# Epoch 78/200
#  - 0s - loss: 0.0673 - val_loss: 0.0636
# Epoch 79/200
#  - 0s - loss: 0.0672 - val_loss: 0.0637
# Epoch 80/200
#  - 0s - loss: 0.0674 - val_loss: 0.0635
# Epoch 81/200
#  - 0s - loss: 0.0673 - val_loss: 0.0644
# Epoch 82/200
#  - 0s - loss: 0.0674 - val_loss: 0.0639
# Epoch 83/200
#  - 0s - loss: 0.0675 - val_loss: 0.0635
# Epoch 84/200
#  - 0s - loss: 0.0672 - val_loss: 0.0657
# Epoch 85/200
#  - 0s - loss: 0.0672 - val_loss: 0.0642
# Epoch 86/200
#  - 0s - loss: 0.0674 - val_loss: 0.0644
# Epoch 87/200
#  - 0s - loss: 0.0673 - val_loss: 0.0671
# Epoch 88/200
#  - 0s - loss: 0.0674 - val_loss: 0.0636
# Epoch 89/200
#  - 0s - loss: 0.0671 - val_loss: 0.0688
# Epoch 90/200
#  - 0s - loss: 0.0673 - val_loss: 0.0647
# Epoch 91/200
#  - 0s - loss: 0.0673 - val_loss: 0.0636
# Epoch 92/200
#  - 0s - loss: 0.0673 - val_loss: 0.0664
# Epoch 93/200
#  - 0s - loss: 0.0673 - val_loss: 0.0643
# Epoch 94/200
#  - 0s - loss: 0.0671 - val_loss: 0.0635
# Epoch 95/200
#  - 0s - loss: 0.0671 - val_loss: 0.0635
# Epoch 96/200
#  - 0s - loss: 0.0673 - val_loss: 0.0648
# Epoch 97/200
#  - 0s - loss: 0.0673 - val_loss: 0.0675
# Epoch 98/200
#  - 0s - loss: 0.0673 - val_loss: 0.0635
# Epoch 99/200
#  - 0s - loss: 0.0673 - val_loss: 0.0648
# Epoch 100/200
#  - 0s - loss: 0.0673 - val_loss: 0.0635
# Epoch 101/200
#  - 0s - loss: 0.0671 - val_loss: 0.0645
# Epoch 102/200
#  - 0s - loss: 0.0672 - val_loss: 0.0647
# Epoch 103/200
#  - 0s - loss: 0.0672 - val_loss: 0.0636
# Epoch 104/200
#  - 0s - loss: 0.0673 - val_loss: 0.0634
# Epoch 105/200
#  - 0s - loss: 0.0673 - val_loss: 0.0648
# Epoch 106/200
#  - 0s - loss: 0.0672 - val_loss: 0.0639
# Epoch 107/200
#  - 0s - loss: 0.0672 - val_loss: 0.0634
# Epoch 108/200
#  - 0s - loss: 0.0673 - val_loss: 0.0656
# Epoch 109/200
#  - 0s - loss: 0.0673 - val_loss: 0.0635
# Epoch 110/200
#  - 0s - loss: 0.0671 - val_loss: 0.0634
# Epoch 111/200
#  - 0s - loss: 0.0671 - val_loss: 0.0635
# Epoch 112/200
#  - 0s - loss: 0.0671 - val_loss: 0.0635
# Epoch 113/200
#  - 0s - loss: 0.0672 - val_loss: 0.0671
# Epoch 114/200
#  - 0s - loss: 0.0671 - val_loss: 0.0634
# Epoch 115/200
#  - 0s - loss: 0.0673 - val_loss: 0.0643
# Epoch 116/200
#  - 0s - loss: 0.0671 - val_loss: 0.0637
# Epoch 117/200
#  - 0s - loss: 0.0671 - val_loss: 0.0646
# Epoch 118/200
#  - 0s - loss: 0.0672 - val_loss: 0.0635
# Epoch 119/200
#  - 0s - loss: 0.0670 - val_loss: 0.0640
# Epoch 120/200
#  - 0s - loss: 0.0670 - val_loss: 0.0640
# Epoch 121/200
#  - 0s - loss: 0.0672 - val_loss: 0.0637
# Epoch 122/200
#  - 0s - loss: 0.0672 - val_loss: 0.0635
# Epoch 123/200
#  - 0s - loss: 0.0673 - val_loss: 0.0635
# Epoch 124/200
#  - 0s - loss: 0.0670 - val_loss: 0.0635
# Epoch 125/200
#  - 0s - loss: 0.0671 - val_loss: 0.0637
# Epoch 126/200
#  - 0s - loss: 0.0673 - val_loss: 0.0634
# Epoch 127/200
#  - 0s - loss: 0.0672 - val_loss: 0.0638
# Epoch 128/200
#  - 0s - loss: 0.0671 - val_loss: 0.0634
# Epoch 129/200
#  - 0s - loss: 0.0673 - val_loss: 0.0637
# Epoch 130/200
#  - 0s - loss: 0.0671 - val_loss: 0.0634
# Epoch 131/200
#  - 0s - loss: 0.0671 - val_loss: 0.0637
# Epoch 132/200
#  - 0s - loss: 0.0672 - val_loss: 0.0653
# Epoch 133/200
#  - 0s - loss: 0.0671 - val_loss: 0.0646
# Epoch 134/200
#  - 0s - loss: 0.0671 - val_loss: 0.0646
# Epoch 135/200
#  - 0s - loss: 0.0673 - val_loss: 0.0646
# Epoch 136/200
#  - 0s - loss: 0.0673 - val_loss: 0.0638
# Epoch 137/200
#  - 0s - loss: 0.0674 - val_loss: 0.0634
# Epoch 138/200
#  - 0s - loss: 0.0671 - val_loss: 0.0634
# Epoch 139/200
#  - 0s - loss: 0.0672 - val_loss: 0.0638
# Epoch 140/200
#  - 0s - loss: 0.0672 - val_loss: 0.0666
# Epoch 141/200
#  - 0s - loss: 0.0670 - val_loss: 0.0636
# Epoch 142/200
#  - 0s - loss: 0.0668 - val_loss: 0.0640
# Epoch 143/200
#  - 0s - loss: 0.0670 - val_loss: 0.0658
# Epoch 144/200
#  - 0s - loss: 0.0672 - val_loss: 0.0634
# Epoch 145/200
#  - 0s - loss: 0.0672 - val_loss: 0.0637
# Epoch 146/200
#  - 0s - loss: 0.0670 - val_loss: 0.0634
# Epoch 147/200
#  - 0s - loss: 0.0669 - val_loss: 0.0655
# Epoch 148/200
#  - 0s - loss: 0.0669 - val_loss: 0.0640
# Epoch 149/200
#  - 0s - loss: 0.0670 - val_loss: 0.0634
# Epoch 150/200
#  - 0s - loss: 0.0673 - val_loss: 0.0636
# Epoch 151/200
#  - 0s - loss: 0.0671 - val_loss: 0.0640
# Epoch 152/200
#  - 0s - loss: 0.0670 - val_loss: 0.0634
# Epoch 153/200
#  - 0s - loss: 0.0673 - val_loss: 0.0634
# Epoch 154/200
#  - 0s - loss: 0.0672 - val_loss: 0.0639
# Epoch 155/200
#  - 0s - loss: 0.0673 - val_loss: 0.0634
# Epoch 156/200
#  - 0s - loss: 0.0672 - val_loss: 0.0635
# Epoch 157/200
#  - 0s - loss: 0.0672 - val_loss: 0.0640
# Epoch 158/200
#  - 0s - loss: 0.0673 - val_loss: 0.0643
# Epoch 159/200
#  - 0s - loss: 0.0670 - val_loss: 0.0637
# Epoch 160/200
#  - 0s - loss: 0.0673 - val_loss: 0.0640
# Epoch 161/200
#  - 0s - loss: 0.0672 - val_loss: 0.0643
# Epoch 162/200
#  - 0s - loss: 0.0671 - val_loss: 0.0634
# Epoch 163/200
#  - 0s - loss: 0.0668 - val_loss: 0.0645
# Epoch 164/200
#  - 0s - loss: 0.0673 - val_loss: 0.0651
# Epoch 165/200
#  - 0s - loss: 0.0671 - val_loss: 0.0637
# Epoch 166/200
#  - 0s - loss: 0.0673 - val_loss: 0.0655
# Epoch 167/200
#  - 0s - loss: 0.0672 - val_loss: 0.0635
# Epoch 168/200
#  - 0s - loss: 0.0669 - val_loss: 0.0639
# Minimum validation loss of 0.06338366901520455 reached at epoch 137

# %%
simple_lstm = Sequential()
simple_lstm.add(LSTM(5, input_shape=(train_X.shape[1], train_X.shape[2])))
simple_lstm.add(Dense(1))
simple_lstm.compile(loss='mae', optimizer=RMSprop())

#checkpointer = ModelCheckpoint(filepath='simple_lstm_weights.hdf5'
#                               , verbose=0
#                               , save_best_only=True)
earlystopper = EarlyStopping(monitor='val_loss'
                             , patience=30
                             , verbose=0)
with open("simple_lstm.json", "w") as m:
    m.write(simple_lstm.to_json())

simple_lstm_history = simple_lstm.fit(train_X,train_y
                                              , epochs=200
                                              , validation_data=(val_X, val_y)
                                              , verbose=2
                                              , callbacks= [earlystopper]
                                             )
plot_loss(simple_lstm_history, 'Simple LSTM - Train & Validation Loss')
# Out:
# Train on 3100 samples, validate on 505 samples
# Epoch 1/200
#  - 1s - loss: 0.1573 - val_loss: 0.0776
# Epoch 2/200
#  - 1s - loss: 0.0784 - val_loss: 0.0731
# Epoch 3/200
#  - 1s - loss: 0.0757 - val_loss: 0.0713
# Epoch 4/200
#  - 1s - loss: 0.0742 - val_loss: 0.0701
# Epoch 5/200
#  - 1s - loss: 0.0731 - val_loss: 0.0692
# Epoch 6/200
#  - 1s - loss: 0.0721 - val_loss: 0.0690
# Epoch 7/200
#  - 1s - loss: 0.0714 - val_loss: 0.0679
# Epoch 8/200
#  - 1s - loss: 0.0710 - val_loss: 0.0673
# Epoch 9/200
#  - 1s - loss: 0.0704 - val_loss: 0.0671
# Epoch 10/200
#  - 1s - loss: 0.0699 - val_loss: 0.0680
# Epoch 11/200
#  - 1s - loss: 0.0695 - val_loss: 0.0672
# Epoch 12/200
#  - 1s - loss: 0.0693 - val_loss: 0.0660
# Epoch 13/200
#  - 1s - loss: 0.0690 - val_loss: 0.0654
# Epoch 14/200
#  - 1s - loss: 0.0687 - val_loss: 0.0653
# Epoch 15/200
#  - 1s - loss: 0.0685 - val_loss: 0.0650
# Epoch 16/200
#  - 1s - loss: 0.0683 - val_loss: 0.0647
# Epoch 17/200
#  - 1s - loss: 0.0680 - val_loss: 0.0643
# Epoch 18/200
#  - 1s - loss: 0.0679 - val_loss: 0.0646
# Epoch 19/200
#  - 1s - loss: 0.0678 - val_loss: 0.0646
# Epoch 20/200
#  - 1s - loss: 0.0675 - val_loss: 0.0638
# Epoch 21/200
#  - 1s - loss: 0.0675 - val_loss: 0.0638
# Epoch 22/200
#  - 1s - loss: 0.0673 - val_loss: 0.0642
# Epoch 23/200
#  - 1s - loss: 0.0673 - val_loss: 0.0636
# Epoch 24/200
#  - 1s - loss: 0.0672 - val_loss: 0.0640
# Epoch 25/200
#  - 1s - loss: 0.0672 - val_loss: 0.0635
# Epoch 26/200
#  - 1s - loss: 0.0671 - val_loss: 0.0635
# Epoch 27/200
#  - 1s - loss: 0.0671 - val_loss: 0.0634
# Epoch 28/200
#  - 1s - loss: 0.0671 - val_loss: 0.0638
# Epoch 29/200
#  - 1s - loss: 0.0669 - val_loss: 0.0635
# Epoch 30/200
#  - 1s - loss: 0.0669 - val_loss: 0.0635
# Epoch 31/200
#  - 1s - loss: 0.0670 - val_loss: 0.0637
# Epoch 32/200
#  - 1s - loss: 0.0669 - val_loss: 0.0649
# Epoch 33/200
#  - 1s - loss: 0.0667 - val_loss: 0.0646
# Epoch 34/200
#  - 1s - loss: 0.0668 - val_loss: 0.0635
# Epoch 35/200
#  - 1s - loss: 0.0669 - val_loss: 0.0632
# Epoch 36/200
#  - 1s - loss: 0.0669 - val_loss: 0.0632
# Epoch 37/200
#  - 1s - loss: 0.0668 - val_loss: 0.0642
# Epoch 38/200
#  - 1s - loss: 0.0668 - val_loss: 0.0632
# Epoch 39/200
#  - 1s - loss: 0.0667 - val_loss: 0.0633
# Epoch 40/200
#  - 1s - loss: 0.0669 - val_loss: 0.0632
# Epoch 41/200
#  - 1s - loss: 0.0669 - val_loss: 0.0633
# Epoch 42/200
#  - 1s - loss: 0.0669 - val_loss: 0.0634
# Epoch 43/200
#  - 1s - loss: 0.0668 - val_loss: 0.0632
# Epoch 44/200
#  - 1s - loss: 0.0667 - val_loss: 0.0633
# Epoch 45/200
#  - 1s - loss: 0.0669 - val_loss: 0.0633
# Epoch 46/200
#  - 1s - loss: 0.0668 - val_loss: 0.0633
# Epoch 47/200
#  - 1s - loss: 0.0668 - val_loss: 0.0638
# Epoch 48/200
#  - 1s - loss: 0.0668 - val_loss: 0.0632
# Epoch 49/200
#  - 1s - loss: 0.0668 - val_loss: 0.0633
# Epoch 50/200
#  - 1s - loss: 0.0667 - val_loss: 0.0632
# Epoch 51/200
#  - 1s - loss: 0.0668 - val_loss: 0.0635
# Epoch 52/200
#  - 1s - loss: 0.0668 - val_loss: 0.0632
# Epoch 53/200
#  - 1s - loss: 0.0668 - val_loss: 0.0641
# Epoch 54/200
#  - 1s - loss: 0.0667 - val_loss: 0.0636
# Epoch 55/200
#  - 1s - loss: 0.0667 - val_loss: 0.0651
# Epoch 56/200
#  - 1s - loss: 0.0667 - val_loss: 0.0635
# Epoch 57/200
#  - 1s - loss: 0.0665 - val_loss: 0.0632
# Epoch 58/200
#  - 1s - loss: 0.0666 - val_loss: 0.0633
# Epoch 59/200
#  - 1s - loss: 0.0667 - val_loss: 0.0639
# Epoch 60/200
#  - 1s - loss: 0.0668 - val_loss: 0.0635
# Epoch 61/200
#  - 1s - loss: 0.0666 - val_loss: 0.0637
# Epoch 62/200
#  - 1s - loss: 0.0666 - val_loss: 0.0633
# Epoch 63/200
#  - 1s - loss: 0.0668 - val_loss: 0.0632
# Epoch 64/200
#  - 1s - loss: 0.0666 - val_loss: 0.0632
# Epoch 65/200
#  - 1s - loss: 0.0668 - val_loss: 0.0632
# Epoch 66/200
#  - 1s - loss: 0.0668 - val_loss: 0.0645
# Epoch 67/200
#  - 1s - loss: 0.0668 - val_loss: 0.0632
# Epoch 68/200
#  - 1s - loss: 0.0667 - val_loss: 0.0636
# Epoch 69/200
#  - 1s - loss: 0.0668 - val_loss: 0.0631
# Epoch 70/200
#  - 1s - loss: 0.0668 - val_loss: 0.0633
# Epoch 71/200
#  - 1s - loss: 0.0667 - val_loss: 0.0641
# Epoch 72/200
#  - 1s - loss: 0.0668 - val_loss: 0.0634
# Epoch 73/200
#  - 1s - loss: 0.0666 - val_loss: 0.0641
# Epoch 74/200
#  - 1s - loss: 0.0666 - val_loss: 0.0631
# Epoch 75/200
#  - 1s - loss: 0.0668 - val_loss: 0.0632
# Epoch 76/200
#  - 1s - loss: 0.0668 - val_loss: 0.0633
# Epoch 77/200
#  - 1s - loss: 0.0667 - val_loss: 0.0633
# Epoch 78/200
#  - 1s - loss: 0.0667 - val_loss: 0.0631
# Epoch 79/200
#  - 1s - loss: 0.0668 - val_loss: 0.0631
# Epoch 80/200
#  - 1s - loss: 0.0669 - val_loss: 0.0632
# Epoch 81/200
#  - 1s - loss: 0.0667 - val_loss: 0.0653
# Epoch 82/200
#  - 1s - loss: 0.0667 - val_loss: 0.0639
# Epoch 83/200
#  - 1s - loss: 0.0668 - val_loss: 0.0640
# Epoch 84/200
#  - 1s - loss: 0.0667 - val_loss: 0.0633
# Epoch 85/200
#  - 1s - loss: 0.0667 - val_loss: 0.0632
# Epoch 86/200
#  - 1s - loss: 0.0666 - val_loss: 0.0632
# Epoch 87/200
#  - 1s - loss: 0.0666 - val_loss: 0.0635
# Epoch 88/200
#  - 1s - loss: 0.0666 - val_loss: 0.0640
# Epoch 89/200
#  - 1s - loss: 0.0667 - val_loss: 0.0635
# Epoch 90/200
#  - 1s - loss: 0.0668 - val_loss: 0.0633
# Epoch 91/200
#  - 1s - loss: 0.0666 - val_loss: 0.0637
# Epoch 92/200
#  - 1s - loss: 0.0667 - val_loss: 0.0632
# Epoch 93/200
#  - 1s - loss: 0.0666 - val_loss: 0.0632
# Epoch 94/200
#  - 1s - loss: 0.0669 - val_loss: 0.0632
# Epoch 95/200
#  - 1s - loss: 0.0667 - val_loss: 0.0635
# Epoch 96/200
#  - 1s - loss: 0.0667 - val_loss: 0.0633
# Epoch 97/200
#  - 1s - loss: 0.0666 - val_loss: 0.0633
# Epoch 98/200
#  - 1s - loss: 0.0667 - val_loss: 0.0636
# Epoch 99/200
#  - 1s - loss: 0.0666 - val_loss: 0.0636
# Minimum validation loss of 0.06312992535900361 reached at epoch 68

# %%
stacked_lstm = Sequential()
stacked_lstm.add(LSTM(16, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
stacked_lstm.add(LSTM(8, return_sequences=True))
stacked_lstm.add(LSTM(4))
stacked_lstm.add(Dense(1))
stacked_lstm.compile(loss='mae', optimizer=RMSprop())

#checkpointer = ModelCheckpoint(filepath='stacked_lstm_weights.hdf5'
#                               , verbose=0
#                               , save_best_only=True)
earlystopper = EarlyStopping(monitor='val_loss'
                             , patience=30
                             , verbose=0)
with open("stacked_lstm.json", "w") as m:
    m.write(stacked_lstm.to_json())

stacked_lstm_history = stacked_lstm.fit(train_X,train_y
                                              , epochs=200
                                              , validation_data=(val_X, val_y)
                                              , verbose=2
                                              , callbacks= [earlystopper]
                                             )
plot_loss(stacked_lstm_history, 'Stacked LSTM - Train & Validation Loss')
# Out:
# Train on 3100 samples, validate on 505 samples
# Epoch 1/200
#  - 2s - loss: 0.2556 - val_loss: 0.0889
# Epoch 2/200
#  - 2s - loss: 0.0843 - val_loss: 0.0792
# Epoch 3/200
#  - 1s - loss: 0.0795 - val_loss: 0.0739
# Epoch 4/200
#  - 1s - loss: 0.0763 - val_loss: 0.0711
# Epoch 5/200
#  - 1s - loss: 0.0746 - val_loss: 0.0696
# Epoch 6/200
#  - 1s - loss: 0.0733 - val_loss: 0.0685
# Epoch 7/200
#  - 1s - loss: 0.0724 - val_loss: 0.0697
# Epoch 8/200
#  - 1s - loss: 0.0715 - val_loss: 0.0684
# Epoch 9/200
#  - 1s - loss: 0.0709 - val_loss: 0.0682
# Epoch 10/200
#  - 1s - loss: 0.0700 - val_loss: 0.0662
# Epoch 11/200
#  - 1s - loss: 0.0692 - val_loss: 0.0656
# Epoch 12/200
#  - 1s - loss: 0.0692 - val_loss: 0.0653
# Epoch 13/200
#  - 1s - loss: 0.0690 - val_loss: 0.0650
# Epoch 14/200
#  - 1s - loss: 0.0685 - val_loss: 0.0646
# Epoch 15/200
#  - 1s - loss: 0.0681 - val_loss: 0.0682
# Epoch 16/200
#  - 1s - loss: 0.0682 - val_loss: 0.0652
# Epoch 17/200
#  - 1s - loss: 0.0679 - val_loss: 0.0649
# Epoch 18/200
#  - 1s - loss: 0.0677 - val_loss: 0.0641
# Epoch 19/200
#  - 1s - loss: 0.0676 - val_loss: 0.0637
# Epoch 20/200
#  - 1s - loss: 0.0675 - val_loss: 0.0643
# Epoch 21/200
#  - 1s - loss: 0.0675 - val_loss: 0.0636
# Epoch 22/200
#  - 1s - loss: 0.0675 - val_loss: 0.0660
# Epoch 23/200
#  - 1s - loss: 0.0676 - val_loss: 0.0634
# Epoch 24/200
#  - 1s - loss: 0.0672 - val_loss: 0.0646
# Epoch 25/200
#  - 1s - loss: 0.0674 - val_loss: 0.0652
# Epoch 26/200
#  - 1s - loss: 0.0674 - val_loss: 0.0634
# Epoch 27/200
#  - 1s - loss: 0.0672 - val_loss: 0.0635
# Epoch 28/200
#  - 1s - loss: 0.0672 - val_loss: 0.0632
# Epoch 29/200
#  - 1s - loss: 0.0671 - val_loss: 0.0640
# Epoch 30/200
#  - 1s - loss: 0.0672 - val_loss: 0.0637
# Epoch 31/200
#  - 1s - loss: 0.0670 - val_loss: 0.0636
# Epoch 32/200
#  - 1s - loss: 0.0673 - val_loss: 0.0648
# Epoch 33/200
#  - 1s - loss: 0.0672 - val_loss: 0.0635
# Epoch 34/200
#  - 1s - loss: 0.0671 - val_loss: 0.0631
# Epoch 35/200
#  - 1s - loss: 0.0673 - val_loss: 0.0636
# Epoch 36/200
#  - 1s - loss: 0.0670 - val_loss: 0.0631
# Epoch 37/200
#  - 1s - loss: 0.0672 - val_loss: 0.0632
# Epoch 38/200
#  - 1s - loss: 0.0671 - val_loss: 0.0632
# Epoch 39/200
#  - 1s - loss: 0.0670 - val_loss: 0.0644
# Epoch 40/200
#  - 1s - loss: 0.0671 - val_loss: 0.0631
# Epoch 41/200
#  - 1s - loss: 0.0670 - val_loss: 0.0641
# Epoch 42/200
#  - 1s - loss: 0.0672 - val_loss: 0.0632
# Epoch 43/200
#  - 1s - loss: 0.0673 - val_loss: 0.0635
# Epoch 44/200
#  - 1s - loss: 0.0671 - val_loss: 0.0637
# Epoch 45/200
#  - 1s - loss: 0.0670 - val_loss: 0.0632
# Epoch 46/200
#  - 1s - loss: 0.0671 - val_loss: 0.0634
# Epoch 47/200
#  - 1s - loss: 0.0670 - val_loss: 0.0633
# Epoch 48/200
#  - 1s - loss: 0.0670 - val_loss: 0.0655
# Epoch 49/200
#  - 1s - loss: 0.0669 - val_loss: 0.0634
# Epoch 50/200
#  - 1s - loss: 0.0671 - val_loss: 0.0631
# Epoch 51/200
#  - 1s - loss: 0.0670 - val_loss: 0.0655
# Epoch 52/200
#  - 1s - loss: 0.0668 - val_loss: 0.0644
# Epoch 53/200
#  - 1s - loss: 0.0670 - val_loss: 0.0635
# Epoch 54/200
#  - 1s - loss: 0.0670 - val_loss: 0.0669
# Epoch 55/200
#  - 1s - loss: 0.0670 - val_loss: 0.0632
# Epoch 56/200
#  - 1s - loss: 0.0670 - val_loss: 0.0650
# Epoch 57/200
#  - 1s - loss: 0.0668 - val_loss: 0.0646
# Epoch 58/200
#  - 1s - loss: 0.0670 - val_loss: 0.0630
# Epoch 59/200
#  - 1s - loss: 0.0671 - val_loss: 0.0634
# Epoch 60/200
#  - 1s - loss: 0.0669 - val_loss: 0.0638
# Epoch 61/200
#  - 1s - loss: 0.0670 - val_loss: 0.0631
# Epoch 62/200
#  - 1s - loss: 0.0669 - val_loss: 0.0630
# Epoch 63/200
#  - 1s - loss: 0.0669 - val_loss: 0.0634
# Epoch 64/200
#  - 1s - loss: 0.0669 - val_loss: 0.0641
# Epoch 65/200
#  - 1s - loss: 0.0670 - val_loss: 0.0633
# Epoch 66/200
#  - 1s - loss: 0.0668 - val_loss: 0.0660
# Epoch 67/200
#  - 1s - loss: 0.0667 - val_loss: 0.0633
# Epoch 68/200
#  - 1s - loss: 0.0668 - val_loss: 0.0632
# Epoch 69/200
#  - 1s - loss: 0.0670 - val_loss: 0.0631
# Epoch 70/200
#  - 1s - loss: 0.0669 - val_loss: 0.0631
# Epoch 71/200
#  - 1s - loss: 0.0669 - val_loss: 0.0645
# Epoch 72/200
#  - 1s - loss: 0.0671 - val_loss: 0.0631
# Epoch 73/200
#  - 1s - loss: 0.0670 - val_loss: 0.0634
# Epoch 74/200
#  - 1s - loss: 0.0669 - val_loss: 0.0630
# Epoch 75/200
#  - 1s - loss: 0.0669 - val_loss: 0.0634
# Epoch 76/200
#  - 1s - loss: 0.0669 - val_loss: 0.0674
# Epoch 77/200
#  - 1s - loss: 0.0668 - val_loss: 0.0632
# Epoch 78/200
#  - 2s - loss: 0.0669 - val_loss: 0.0682
# Epoch 79/200
#  - 2s - loss: 0.0670 - val_loss: 0.0640
# Epoch 80/200
#  - 1s - loss: 0.0668 - val_loss: 0.0635
# Epoch 81/200
#  - 1s - loss: 0.0667 - val_loss: 0.0631
# Epoch 82/200
#  - 1s - loss: 0.0668 - val_loss: 0.0636
# Epoch 83/200
#  - 1s - loss: 0.0668 - val_loss: 0.0634
# Epoch 84/200
#  - 1s - loss: 0.0670 - val_loss: 0.0639
# Epoch 85/200
#  - 1s - loss: 0.0668 - val_loss: 0.0638
# Epoch 86/200
#  - 1s - loss: 0.0668 - val_loss: 0.0635
# Epoch 87/200
#  - 1s - loss: 0.0668 - val_loss: 0.0631
# Epoch 88/200
#  - 1s - loss: 0.0668 - val_loss: 0.0631
# Epoch 89/200
#  - 1s - loss: 0.0671 - val_loss: 0.0635
# Epoch 90/200
#  - 1s - loss: 0.0669 - val_loss: 0.0630
# Epoch 91/200
#  - 1s - loss: 0.0669 - val_loss: 0.0644
# Epoch 92/200
#  - 1s - loss: 0.0670 - val_loss: 0.0630
# Minimum validation loss of 0.06301594879662636 reached at epoch 61

# %%
preds = []
preds_array = stacked_lstm.predict(test_X)
for i in range(len(preds_array)):
    preds.append(preds_array[i][0])

train_data = pd.DataFrame({
    'Ozone Concentration':train_y,
    'Date':df.index[7:3107]
})
train_data['Observation Type'] = 'Actual'

val_data = pd.DataFrame({
    'Ozone Concentration':val_y,
    'Date':df.index[3107:-360]
})
val_data['Observation Type'] = 'Actual'

test_data = pd.DataFrame({
    'Ozone Concentration':preds,
    'Date':df.index[-360:]
})
test_data['Observation Type'] = 'Predicted'

plot_me = pd.concat([train_data,val_data,test_data])

sns.lineplot(x=plot_me.Date,y=plot_me['Ozone Concentration'],hue=plot_me['Observation Type'])

# %%
sns.lineplot(x=df.index,y=df['Daily Max 8-hour Ozone Concentration'])
