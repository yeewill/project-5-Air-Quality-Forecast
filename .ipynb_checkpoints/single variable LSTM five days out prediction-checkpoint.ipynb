# %%
import pickle
import pandas as pd
import seaborn as sns

# %%
air_df = pickle.load(open("air_df_1.p",'rb'))
open('air_df_1.p','rb').close
# Out:
# <function BufferedReader.close>

# %%
air_df.sort_values(by='Date',inplace=True)
df =air_df[['Date','Daily Max 8-hour Ozone Concentration']]
df.set_index('Date',inplace=True)

# %%
import plaidml.keras
plaidml.keras.install_backend()

from pathlib import Path
import pandas as pd
import numpy as np
import pandas_profiling
# %matplotlib inline
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)

from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense, LSTM, SimpleRNN
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import model_from_json

# %%
def plot_loss(history, title):
    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title(title)
    plt.xlabel('Nb Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    val_loss = history.history['val_loss']
    min_idx = np.argmin(val_loss)
    min_val_loss = val_loss[min_idx]
    print('Minimum validation loss of {} reached at epoch {}'.format(min_val_loss, min_idx))

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# load dataset
values = df.values
# integer encode direction
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler()
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 7, 2)
# drop columns we don't want to predict
reframed.head()
# Out:
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 7    0.246377   0.347826   0.434783   0.521739   0.478261   0.391304
# 8    0.347826   0.434783   0.521739   0.478261   0.391304   0.405797
# 9    0.434783   0.521739   0.478261   0.391304   0.405797   0.260870
# 10   0.521739   0.478261   0.391304   0.405797   0.260870   0.043478
# 11   0.478261   0.391304   0.405797   0.260870   0.043478   0.014493
#
#     var1(t-1)   var1(t)  var1(t+1)
# 7    0.405797  0.260870   0.043478
# 8    0.260870  0.043478   0.014493
# 9    0.043478  0.014493   0.115942
# 10   0.014493  0.115942   0.202899
# 11   0.115942  0.202899   0.217391

# %%
y = reframed.iloc[:,-1].values
X = reframed.drop(['var1(t)','var1(t+1)'], axis =1).values
# split into train and test sets

n_train_days = 3100
n_test_days=360
train_X = X[:n_train_days,:]
train_y = y[:n_train_days]

val_X= X[n_train_days:-n_test_days,]
val_y= y[n_train_days:-n_test_days]

test_X = X[-n_test_days:,:]
test_y = y[-n_test_days:]



# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape,val_X.shape, val_y.shape ,test_X.shape, test_y.shape)
# Out:
# (3100, 1, 7) (3100,) (504, 1, 7) (504,) (360, 1, 7) (360,)

# %%
simple_rnn = Sequential()
simple_rnn.add(SimpleRNN(5, input_shape=(train_X.shape[1], train_X.shape[2])))
simple_rnn.add(Dense(1))
simple_rnn.compile(loss='mae', optimizer=RMSprop())

#checkpointer = ModelCheckpoint(filepath='simple_rnn_weights.hdf5'
#                               , verbose=0
#                               , save_best_only=True)
earlystopper = EarlyStopping(monitor='val_loss'
                             , patience=30
                             , verbose=0)
with open("simple_rnn.json", "w") as m:
     m.write(simple_rnn.to_json())

simple_rnn_history = simple_rnn.fit(train_X,train_y
                                              , epochs=200
                                              , validation_data=(val_X, val_y)
                                              , verbose=2
                                              , callbacks= [earlystopper]
                                             )
plot_loss(simple_rnn_history, 'SimpleRNN - Train & Validation Loss')
# Out:
# INFO:plaidml:Opening device "opencl_amd_radeon_pro_560x_compute_engine.0"
# Train on 3100 samples, validate on 504 samples
# Epoch 1/200
#  - 1s - loss: 0.1776 - val_loss: 0.0961
# Epoch 2/200
#  - 0s - loss: 0.0971 - val_loss: 0.0925
# Epoch 3/200
#  - 0s - loss: 0.0937 - val_loss: 0.0885
# Epoch 4/200
#  - 0s - loss: 0.0906 - val_loss: 0.0861
# Epoch 5/200
#  - 0s - loss: 0.0886 - val_loss: 0.0866
# Epoch 6/200
#  - 0s - loss: 0.0871 - val_loss: 0.0848
# Epoch 7/200
#  - 0s - loss: 0.0861 - val_loss: 0.0841
# Epoch 8/200
#  - 0s - loss: 0.0852 - val_loss: 0.0813
# Epoch 9/200
#  - 0s - loss: 0.0846 - val_loss: 0.0802
# Epoch 10/200
#  - 0s - loss: 0.0842 - val_loss: 0.0798
# Epoch 11/200
#  - 0s - loss: 0.0837 - val_loss: 0.0796
# Epoch 12/200
#  - 1s - loss: 0.0833 - val_loss: 0.0796
# Epoch 13/200
#  - 0s - loss: 0.0834 - val_loss: 0.0792
# Epoch 14/200
#  - 1s - loss: 0.0831 - val_loss: 0.0795
# Epoch 15/200
#  - 1s - loss: 0.0827 - val_loss: 0.0785
# Epoch 16/200
#  - 1s - loss: 0.0825 - val_loss: 0.0784
# Epoch 17/200
#  - 1s - loss: 0.0823 - val_loss: 0.0802
# Epoch 18/200
#  - 0s - loss: 0.0822 - val_loss: 0.0789
# Epoch 19/200
#  - 0s - loss: 0.0822 - val_loss: 0.0816
# Epoch 20/200
#  - 0s - loss: 0.0820 - val_loss: 0.0781
# Epoch 21/200
#  - 0s - loss: 0.0819 - val_loss: 0.0784
# Epoch 22/200
#  - 0s - loss: 0.0818 - val_loss: 0.0782
# Epoch 23/200
#  - 0s - loss: 0.0817 - val_loss: 0.0781
# Epoch 24/200
#  - 0s - loss: 0.0816 - val_loss: 0.0786
# Epoch 25/200
#  - 0s - loss: 0.0815 - val_loss: 0.0779
# Epoch 26/200
#  - 0s - loss: 0.0814 - val_loss: 0.0781
# Epoch 27/200
#  - 0s - loss: 0.0813 - val_loss: 0.0781
# Epoch 28/200
#  - 0s - loss: 0.0814 - val_loss: 0.0786
# Epoch 29/200
#  - 0s - loss: 0.0812 - val_loss: 0.0805
# Epoch 30/200
#  - 0s - loss: 0.0813 - val_loss: 0.0794
# Epoch 31/200
#  - 0s - loss: 0.0813 - val_loss: 0.0783
# Epoch 32/200
#  - 0s - loss: 0.0814 - val_loss: 0.0782
# Epoch 33/200
#  - 0s - loss: 0.0813 - val_loss: 0.0779
# Epoch 34/200
#  - 1s - loss: 0.0812 - val_loss: 0.0780
# Epoch 35/200
#  - 0s - loss: 0.0813 - val_loss: 0.0780
# Epoch 36/200
#  - 0s - loss: 0.0810 - val_loss: 0.0783
# Epoch 37/200
#  - 0s - loss: 0.0810 - val_loss: 0.0790
# Epoch 38/200
#  - 0s - loss: 0.0811 - val_loss: 0.0790
# Epoch 39/200
#  - 0s - loss: 0.0812 - val_loss: 0.0790
# Epoch 40/200
#  - 0s - loss: 0.0810 - val_loss: 0.0789
# Epoch 41/200
#  - 0s - loss: 0.0812 - val_loss: 0.0781
# Epoch 42/200
#  - 0s - loss: 0.0810 - val_loss: 0.0790
# Epoch 43/200
#  - 0s - loss: 0.0811 - val_loss: 0.0793
# Epoch 44/200
#  - 0s - loss: 0.0810 - val_loss: 0.0799
# Epoch 45/200
#  - 0s - loss: 0.0809 - val_loss: 0.0780
# Epoch 46/200
#  - 0s - loss: 0.0811 - val_loss: 0.0783
# Epoch 47/200
#  - 0s - loss: 0.0809 - val_loss: 0.0783
# Epoch 48/200
#  - 0s - loss: 0.0810 - val_loss: 0.0781
# Epoch 49/200
#  - 0s - loss: 0.0810 - val_loss: 0.0782
# Epoch 50/200
#  - 0s - loss: 0.0810 - val_loss: 0.0790
# Epoch 51/200
#  - 0s - loss: 0.0809 - val_loss: 0.0780
# Epoch 52/200
#  - 0s - loss: 0.0810 - val_loss: 0.0781
# Epoch 53/200
#  - 0s - loss: 0.0809 - val_loss: 0.0780
# Epoch 54/200
#  - 0s - loss: 0.0810 - val_loss: 0.0790
# Epoch 55/200
#  - 0s - loss: 0.0811 - val_loss: 0.0798
# Epoch 56/200
#  - 0s - loss: 0.0809 - val_loss: 0.0791
# Epoch 57/200
#  - 0s - loss: 0.0810 - val_loss: 0.0782
# Epoch 58/200
#  - 0s - loss: 0.0810 - val_loss: 0.0781
# Epoch 59/200
#  - 0s - loss: 0.0811 - val_loss: 0.0784
# Epoch 60/200
#  - 0s - loss: 0.0809 - val_loss: 0.0781
# Epoch 61/200
#  - 0s - loss: 0.0811 - val_loss: 0.0781
# Epoch 62/200
#  - 0s - loss: 0.0810 - val_loss: 0.0793
# Epoch 63/200
#  - 0s - loss: 0.0809 - val_loss: 0.0780
# Minimum validation loss of 0.077903898698943 reached at epoch 32

# %%
simple_lstm = Sequential()
simple_lstm.add(LSTM(5, input_shape=(train_X.shape[1], train_X.shape[2])))
simple_lstm.add(Dense(1))
simple_lstm.compile(loss='mae', optimizer=RMSprop())

#checkpointer = ModelCheckpoint(filepath='simple_lstm_weights.hdf5'
#                               , verbose=0
#                               , save_best_only=True)
earlystopper = EarlyStopping(monitor='val_loss'
                             , patience=30
                             , verbose=0)
with open("simple_lstm.json", "w") as m:
    m.write(simple_lstm.to_json())

simple_lstm_history = simple_lstm.fit(train_X,train_y
                                              , epochs=200
                                              , validation_data=(val_X, val_y)
                                              , verbose=2
                                              , callbacks= [earlystopper]
                                             )
plot_loss(simple_lstm_history, 'Simple LSTM - Train & Validation Loss')
# Out:
# Train on 3100 samples, validate on 504 samples
# Epoch 1/200
#  - 2s - loss: 0.1475 - val_loss: 0.0831
# Epoch 2/200
#  - 1s - loss: 0.0844 - val_loss: 0.0822
# Epoch 3/200
#  - 1s - loss: 0.0839 - val_loss: 0.0807
# Epoch 4/200
#  - 1s - loss: 0.0833 - val_loss: 0.0814
# Epoch 5/200
#  - 1s - loss: 0.0831 - val_loss: 0.0799
# Epoch 6/200
#  - 1s - loss: 0.0828 - val_loss: 0.0798
# Epoch 7/200
#  - 1s - loss: 0.0825 - val_loss: 0.0820
# Epoch 8/200
#  - 1s - loss: 0.0823 - val_loss: 0.0819
# Epoch 9/200
#  - 1s - loss: 0.0821 - val_loss: 0.0809
# Epoch 10/200
#  - 1s - loss: 0.0821 - val_loss: 0.0796
# Epoch 11/200
#  - 1s - loss: 0.0817 - val_loss: 0.0794
# Epoch 12/200
#  - 1s - loss: 0.0817 - val_loss: 0.0794
# Epoch 13/200
#  - 1s - loss: 0.0817 - val_loss: 0.0791
# Epoch 14/200
#  - 1s - loss: 0.0815 - val_loss: 0.0791
# Epoch 15/200
#  - 1s - loss: 0.0815 - val_loss: 0.0790
# Epoch 16/200
#  - 1s - loss: 0.0814 - val_loss: 0.0790
# Epoch 17/200
#  - 1s - loss: 0.0814 - val_loss: 0.0789
# Epoch 18/200
#  - 1s - loss: 0.0813 - val_loss: 0.0790
# Epoch 19/200
#  - 1s - loss: 0.0813 - val_loss: 0.0788
# Epoch 20/200
#  - 1s - loss: 0.0811 - val_loss: 0.0795
# Epoch 21/200
#  - 1s - loss: 0.0811 - val_loss: 0.0787
# Epoch 22/200
#  - 1s - loss: 0.0811 - val_loss: 0.0787
# Epoch 23/200
#  - 1s - loss: 0.0811 - val_loss: 0.0789
# Epoch 24/200
#  - 1s - loss: 0.0810 - val_loss: 0.0787
# Epoch 25/200
#  - 1s - loss: 0.0811 - val_loss: 0.0785
# Epoch 26/200
#  - 1s - loss: 0.0809 - val_loss: 0.0791
# Epoch 27/200
#  - 1s - loss: 0.0808 - val_loss: 0.0786
# Epoch 28/200
#  - 1s - loss: 0.0809 - val_loss: 0.0788
# Epoch 29/200
#  - 1s - loss: 0.0810 - val_loss: 0.0786
# Epoch 30/200
#  - 1s - loss: 0.0808 - val_loss: 0.0784
# Epoch 31/200
#  - 1s - loss: 0.0809 - val_loss: 0.0785
# Epoch 32/200
#  - 1s - loss: 0.0807 - val_loss: 0.0785
# Epoch 33/200
#  - 1s - loss: 0.0807 - val_loss: 0.0783
# Epoch 34/200
#  - 1s - loss: 0.0807 - val_loss: 0.0783
# Epoch 35/200
#  - 1s - loss: 0.0808 - val_loss: 0.0782
# Epoch 36/200
#  - 1s - loss: 0.0807 - val_loss: 0.0787
# Epoch 37/200
#  - 1s - loss: 0.0808 - val_loss: 0.0784
# Epoch 38/200
#  - 1s - loss: 0.0806 - val_loss: 0.0783
# Epoch 39/200
#  - 1s - loss: 0.0805 - val_loss: 0.0782
# Epoch 40/200
#  - 0s - loss: 0.0807 - val_loss: 0.0784
# Epoch 41/200
#  - 0s - loss: 0.0807 - val_loss: 0.0781
# Epoch 42/200
#  - 0s - loss: 0.0805 - val_loss: 0.0798
# Epoch 43/200
#  - 0s - loss: 0.0806 - val_loss: 0.0782
# Epoch 44/200
#  - 1s - loss: 0.0805 - val_loss: 0.0782
# Epoch 45/200
#  - 1s - loss: 0.0805 - val_loss: 0.0780
# Epoch 46/200
#  - 1s - loss: 0.0807 - val_loss: 0.0789
# Epoch 47/200
#  - 0s - loss: 0.0806 - val_loss: 0.0782
# Epoch 48/200
#  - 0s - loss: 0.0804 - val_loss: 0.0780
# Epoch 49/200
#  - 1s - loss: 0.0805 - val_loss: 0.0784
# Epoch 50/200
#  - 1s - loss: 0.0806 - val_loss: 0.0782
# Epoch 51/200
#  - 1s - loss: 0.0805 - val_loss: 0.0781
# Epoch 52/200
#  - 0s - loss: 0.0805 - val_loss: 0.0782
# Epoch 53/200
#  - 1s - loss: 0.0805 - val_loss: 0.0779
# Epoch 54/200
#  - 0s - loss: 0.0806 - val_loss: 0.0779
# Epoch 55/200
#  - 1s - loss: 0.0804 - val_loss: 0.0792
# Epoch 56/200
#  - 0s - loss: 0.0805 - val_loss: 0.0780
# Epoch 57/200
#  - 1s - loss: 0.0806 - val_loss: 0.0785
# Epoch 58/200
#  - 1s - loss: 0.0805 - val_loss: 0.0780
# Epoch 59/200
#  - 0s - loss: 0.0805 - val_loss: 0.0780
# Epoch 60/200
#  - 0s - loss: 0.0806 - val_loss: 0.0787
# Epoch 61/200
#  - 1s - loss: 0.0804 - val_loss: 0.0785
# Epoch 62/200
#  - 0s - loss: 0.0805 - val_loss: 0.0784
# Epoch 63/200
#  - 1s - loss: 0.0805 - val_loss: 0.0779
# Epoch 64/200
#  - 0s - loss: 0.0804 - val_loss: 0.0785
# Epoch 65/200
#  - 0s - loss: 0.0805 - val_loss: 0.0787
# Epoch 66/200
#  - 0s - loss: 0.0803 - val_loss: 0.0779
# Epoch 67/200
#  - 0s - loss: 0.0804 - val_loss: 0.0780
# Epoch 68/200
#  - 0s - loss: 0.0806 - val_loss: 0.0779
# Epoch 69/200
#  - 0s - loss: 0.0805 - val_loss: 0.0779
# Epoch 70/200
#  - 0s - loss: 0.0804 - val_loss: 0.0793
# Epoch 71/200
#  - 0s - loss: 0.0804 - val_loss: 0.0778
# Epoch 72/200
#  - 0s - loss: 0.0806 - val_loss: 0.0778
# Epoch 73/200
#  - 0s - loss: 0.0804 - val_loss: 0.0778
# Epoch 74/200
#  - 1s - loss: 0.0804 - val_loss: 0.0792
# Epoch 75/200
#  - 0s - loss: 0.0805 - val_loss: 0.0780
# Epoch 76/200
#  - 1s - loss: 0.0804 - val_loss: 0.0779
# Epoch 77/200
#  - 0s - loss: 0.0803 - val_loss: 0.0788
# Epoch 78/200
#  - 0s - loss: 0.0805 - val_loss: 0.0782
# Epoch 79/200
#  - 0s - loss: 0.0804 - val_loss: 0.0778
# Epoch 80/200
#  - 1s - loss: 0.0805 - val_loss: 0.0778
# Epoch 81/200
#  - 1s - loss: 0.0804 - val_loss: 0.0783
# Epoch 82/200
#  - 1s - loss: 0.0805 - val_loss: 0.0780
# Epoch 83/200
#  - 1s - loss: 0.0805 - val_loss: 0.0780
# Epoch 84/200
#  - 1s - loss: 0.0805 - val_loss: 0.0778
# Epoch 85/200
#  - 1s - loss: 0.0803 - val_loss: 0.0782
# Epoch 86/200
#  - 1s - loss: 0.0804 - val_loss: 0.0783
# Epoch 87/200
#  - 1s - loss: 0.0805 - val_loss: 0.0778
# Epoch 88/200
#  - 1s - loss: 0.0804 - val_loss: 0.0778
# Epoch 89/200
#  - 1s - loss: 0.0804 - val_loss: 0.0778
# Epoch 90/200
#  - 1s - loss: 0.0804 - val_loss: 0.0783
# Epoch 91/200
#  - 1s - loss: 0.0803 - val_loss: 0.0780
# Epoch 92/200
#  - 1s - loss: 0.0804 - val_loss: 0.0781
# Epoch 93/200
#  - 1s - loss: 0.0805 - val_loss: 0.0778
# Epoch 94/200
#  - 1s - loss: 0.0804 - val_loss: 0.0779
# Epoch 95/200
#  - 1s - loss: 0.0803 - val_loss: 0.0778
# Epoch 96/200
#  - 1s - loss: 0.0805 - val_loss: 0.0779
# Epoch 97/200
#  - 1s - loss: 0.0804 - val_loss: 0.0779
# Epoch 98/200
#  - 1s - loss: 0.0803 - val_loss: 0.0777
# Epoch 99/200
#  - 1s - loss: 0.0804 - val_loss: 0.0778
# Epoch 100/200
#  - 1s - loss: 0.0804 - val_loss: 0.0777
# Epoch 101/200
#  - 1s - loss: 0.0803 - val_loss: 0.0779
# Epoch 102/200
#  - 1s - loss: 0.0804 - val_loss: 0.0777
# Epoch 103/200
#  - 1s - loss: 0.0804 - val_loss: 0.0778
# Epoch 104/200
#  - 1s - loss: 0.0805 - val_loss: 0.0781
# Epoch 105/200
#  - 1s - loss: 0.0804 - val_loss: 0.0787
# Epoch 106/200
#  - 1s - loss: 0.0804 - val_loss: 0.0777
# Epoch 107/200
#  - 1s - loss: 0.0804 - val_loss: 0.0776
# Epoch 108/200
#  - 1s - loss: 0.0804 - val_loss: 0.0781
# Epoch 109/200
#  - 1s - loss: 0.0804 - val_loss: 0.0798
# Epoch 110/200
#  - 1s - loss: 0.0804 - val_loss: 0.0785
# Epoch 111/200
#  - 1s - loss: 0.0801 - val_loss: 0.0782
# Epoch 112/200
#  - 1s - loss: 0.0804 - val_loss: 0.0778
# Epoch 113/200
#  - 1s - loss: 0.0802 - val_loss: 0.0798
# Epoch 114/200
#  - 1s - loss: 0.0805 - val_loss: 0.0784
# Epoch 115/200
#  - 1s - loss: 0.0804 - val_loss: 0.0778
# Epoch 116/200
#  - 1s - loss: 0.0804 - val_loss: 0.0778
# Epoch 117/200
#  - 1s - loss: 0.0803 - val_loss: 0.0781
# Epoch 118/200
#  - 1s - loss: 0.0803 - val_loss: 0.0779
# Epoch 119/200
#  - 1s - loss: 0.0804 - val_loss: 0.0778
# Epoch 120/200
#  - 1s - loss: 0.0805 - val_loss: 0.0783
# Epoch 121/200
#  - 1s - loss: 0.0803 - val_loss: 0.0778
# Epoch 122/200
#  - 1s - loss: 0.0804 - val_loss: 0.0782
# Epoch 123/200
#  - 1s - loss: 0.0804 - val_loss: 0.0781
# Epoch 124/200
#  - 1s - loss: 0.0803 - val_loss: 0.0777
# Epoch 125/200
#  - 1s - loss: 0.0802 - val_loss: 0.0783
# Epoch 126/200
#  - 1s - loss: 0.0803 - val_loss: 0.0777
# Epoch 127/200
#  - 1s - loss: 0.0804 - val_loss: 0.0793
# Epoch 128/200
#  - 1s - loss: 0.0804 - val_loss: 0.0778
# Epoch 129/200
#  - 1s - loss: 0.0804 - val_loss: 0.0781
# Epoch 130/200
#  - 1s - loss: 0.0803 - val_loss: 0.0781
# Epoch 131/200
#  - 1s - loss: 0.0804 - val_loss: 0.0779
# Epoch 132/200
#  - 1s - loss: 0.0803 - val_loss: 0.0777
# Epoch 133/200
#  - 1s - loss: 0.0804 - val_loss: 0.0782
# Epoch 134/200
#  - 1s - loss: 0.0804 - val_loss: 0.0780
# Epoch 135/200
#  - 1s - loss: 0.0804 - val_loss: 0.0779
# Epoch 136/200
#  - 1s - loss: 0.0803 - val_loss: 0.0779
# Epoch 137/200
#  - 1s - loss: 0.0805 - val_loss: 0.0782
# Minimum validation loss of 0.0776452985074785 reached at epoch 106

# %%
stacked_lstm = Sequential()
stacked_lstm.add(LSTM(16, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
stacked_lstm.add(LSTM(8, return_sequences=True))
stacked_lstm.add(LSTM(4))
stacked_lstm.add(Dense(1))
stacked_lstm.compile(loss='mae', optimizer=RMSprop())

#checkpointer = ModelCheckpoint(filepath='stacked_lstm_weights.hdf5'
#                               , verbose=0
#                               , save_best_only=True)
earlystopper = EarlyStopping(monitor='val_loss'
                             , patience=30
                             , verbose=0)
with open("stacked_lstm.json", "w") as m:
    m.write(stacked_lstm.to_json())

stacked_lstm_history = stacked_lstm.fit(train_X,train_y
                                              , epochs=200
                                              , validation_data=(val_X, val_y)
                                              , verbose=2
                                              , callbacks= [earlystopper]
                                             )
plot_loss(stacked_lstm_history, 'Stacked LSTM - Train & Validation Loss')
# Out:
# Train on 3100 samples, validate on 504 samples
# Epoch 1/200
#  - 3s - loss: 0.2671 - val_loss: 0.1055
# Epoch 2/200
#  - 2s - loss: 0.0906 - val_loss: 0.0846
# Epoch 3/200
#  - 2s - loss: 0.0863 - val_loss: 0.0821
# Epoch 4/200
#  - 1s - loss: 0.0845 - val_loss: 0.0814
# Epoch 5/200
#  - 1s - loss: 0.0836 - val_loss: 0.0795
# Epoch 6/200
#  - 1s - loss: 0.0833 - val_loss: 0.0789
# Epoch 7/200
#  - 1s - loss: 0.0831 - val_loss: 0.0835
# Epoch 8/200
#  - 1s - loss: 0.0829 - val_loss: 0.0786
# Epoch 9/200
#  - 1s - loss: 0.0828 - val_loss: 0.0797
# Epoch 10/200
#  - 1s - loss: 0.0825 - val_loss: 0.0788
# Epoch 11/200
#  - 1s - loss: 0.0823 - val_loss: 0.0783
# Epoch 12/200
#  - 1s - loss: 0.0821 - val_loss: 0.0784
# Epoch 13/200
#  - 1s - loss: 0.0820 - val_loss: 0.0788
# Epoch 14/200
#  - 1s - loss: 0.0818 - val_loss: 0.0782
# Epoch 15/200
#  - 1s - loss: 0.0817 - val_loss: 0.0792
# Epoch 16/200
#  - 1s - loss: 0.0815 - val_loss: 0.0786
# Epoch 17/200
#  - 1s - loss: 0.0816 - val_loss: 0.0781
# Epoch 18/200
#  - 2s - loss: 0.0814 - val_loss: 0.0780
# Epoch 19/200
#  - 1s - loss: 0.0813 - val_loss: 0.0793
# Epoch 20/200
#  - 2s - loss: 0.0812 - val_loss: 0.0794
# Epoch 21/200
#  - 2s - loss: 0.0813 - val_loss: 0.0786
# Epoch 22/200
#  - 2s - loss: 0.0812 - val_loss: 0.0795
# Epoch 23/200
#  - 1s - loss: 0.0812 - val_loss: 0.0788
# Epoch 24/200
#  - 1s - loss: 0.0811 - val_loss: 0.0783
# Epoch 25/200
#  - 1s - loss: 0.0810 - val_loss: 0.0778
# Epoch 26/200
#  - 2s - loss: 0.0810 - val_loss: 0.0791
# Epoch 27/200
#  - 1s - loss: 0.0808 - val_loss: 0.0778
# Epoch 28/200
#  - 1s - loss: 0.0809 - val_loss: 0.0788
# Epoch 29/200
#  - 1s - loss: 0.0811 - val_loss: 0.0781
# Epoch 30/200
#  - 1s - loss: 0.0810 - val_loss: 0.0786
# Epoch 31/200
#  - 1s - loss: 0.0808 - val_loss: 0.0778
# Epoch 32/200
#  - 1s - loss: 0.0809 - val_loss: 0.0778
# Epoch 33/200
#  - 1s - loss: 0.0809 - val_loss: 0.0779
# Epoch 34/200
#  - 1s - loss: 0.0808 - val_loss: 0.0782
# Epoch 35/200
#  - 1s - loss: 0.0807 - val_loss: 0.0789
# Epoch 36/200
#  - 1s - loss: 0.0809 - val_loss: 0.0780
# Epoch 37/200
#  - 1s - loss: 0.0808 - val_loss: 0.0817
# Epoch 38/200
#  - 1s - loss: 0.0807 - val_loss: 0.0782
# Epoch 39/200
#  - 1s - loss: 0.0806 - val_loss: 0.0779
# Epoch 40/200
#  - 1s - loss: 0.0807 - val_loss: 0.0779
# Epoch 41/200
#  - 1s - loss: 0.0807 - val_loss: 0.0777
# Epoch 42/200
#  - 1s - loss: 0.0806 - val_loss: 0.0778
# Epoch 43/200
#  - 1s - loss: 0.0807 - val_loss: 0.0800
# Epoch 44/200
#  - 1s - loss: 0.0808 - val_loss: 0.0777
# Epoch 45/200
#  - 1s - loss: 0.0806 - val_loss: 0.0780
# Epoch 46/200
#  - 1s - loss: 0.0807 - val_loss: 0.0780
# Epoch 47/200
#  - 1s - loss: 0.0804 - val_loss: 0.0781
# Epoch 48/200
#  - 1s - loss: 0.0807 - val_loss: 0.0777
# Epoch 49/200
#  - 1s - loss: 0.0806 - val_loss: 0.0778
# Epoch 50/200
#  - 1s - loss: 0.0805 - val_loss: 0.0806
# Epoch 51/200
#  - 1s - loss: 0.0807 - val_loss: 0.0777
# Epoch 52/200
#  - 1s - loss: 0.0807 - val_loss: 0.0779
# Epoch 53/200
#  - 1s - loss: 0.0806 - val_loss: 0.0781
# Epoch 54/200
#  - 1s - loss: 0.0806 - val_loss: 0.0791
# Epoch 55/200
#  - 1s - loss: 0.0808 - val_loss: 0.0777
# Epoch 56/200
#  - 1s - loss: 0.0807 - val_loss: 0.0777
# Epoch 57/200
#  - 1s - loss: 0.0806 - val_loss: 0.0778
# Epoch 58/200
#  - 1s - loss: 0.0807 - val_loss: 0.0776
# Epoch 59/200
#  - 1s - loss: 0.0806 - val_loss: 0.0780
# Epoch 60/200
#  - 1s - loss: 0.0807 - val_loss: 0.0787
# Epoch 61/200
#  - 1s - loss: 0.0806 - val_loss: 0.0776
# Epoch 62/200
#  - 1s - loss: 0.0806 - val_loss: 0.0782
# Epoch 63/200
#  - 1s - loss: 0.0806 - val_loss: 0.0781
# Epoch 64/200
#  - 1s - loss: 0.0806 - val_loss: 0.0776
# Epoch 65/200
#  - 1s - loss: 0.0807 - val_loss: 0.0786
# Epoch 66/200
#  - 1s - loss: 0.0808 - val_loss: 0.0777
# Epoch 67/200
#  - 1s - loss: 0.0806 - val_loss: 0.0791
# Epoch 68/200
#  - 1s - loss: 0.0807 - val_loss: 0.0787
# Epoch 69/200
#  - 1s - loss: 0.0806 - val_loss: 0.0777
# Epoch 70/200
#  - 1s - loss: 0.0805 - val_loss: 0.0780
# Epoch 71/200
#  - 1s - loss: 0.0806 - val_loss: 0.0782
# Epoch 72/200
#  - 1s - loss: 0.0805 - val_loss: 0.0787
# Epoch 73/200
#  - 1s - loss: 0.0805 - val_loss: 0.0776
# Epoch 74/200
#  - 1s - loss: 0.0807 - val_loss: 0.0777
# Epoch 75/200
#  - 1s - loss: 0.0806 - val_loss: 0.0787
# Epoch 76/200
#  - 1s - loss: 0.0804 - val_loss: 0.0781
# Epoch 77/200
#  - 1s - loss: 0.0805 - val_loss: 0.0782
# Epoch 78/200
#  - 1s - loss: 0.0804 - val_loss: 0.0777
# Epoch 79/200
#  - 1s - loss: 0.0805 - val_loss: 0.0785
# Epoch 80/200
#  - 1s - loss: 0.0804 - val_loss: 0.0778
# Epoch 81/200
#  - 1s - loss: 0.0806 - val_loss: 0.0782
# Epoch 82/200
#  - 1s - loss: 0.0806 - val_loss: 0.0803
# Epoch 83/200
#  - 1s - loss: 0.0808 - val_loss: 0.0777
# Epoch 84/200
#  - 1s - loss: 0.0806 - val_loss: 0.0779
# Epoch 85/200
#  - 1s - loss: 0.0807 - val_loss: 0.0780
# Epoch 86/200
#  - 1s - loss: 0.0803 - val_loss: 0.0779
# Epoch 87/200
#  - 1s - loss: 0.0807 - val_loss: 0.0786
# Epoch 88/200
#  - 1s - loss: 0.0805 - val_loss: 0.0780
# Epoch 89/200
#  - 1s - loss: 0.0806 - val_loss: 0.0778
# Epoch 90/200
#  - 1s - loss: 0.0807 - val_loss: 0.0778
# Epoch 91/200
#  - 1s - loss: 0.0805 - val_loss: 0.0785
# Epoch 92/200
#  - 1s - loss: 0.0803 - val_loss: 0.0812
# Epoch 93/200
#  - 1s - loss: 0.0805 - val_loss: 0.0776
# Epoch 94/200
#  - 1s - loss: 0.0806 - val_loss: 0.0777
# Epoch 95/200
#  - 1s - loss: 0.0806 - val_loss: 0.0781
# Epoch 96/200
#  - 1s - loss: 0.0806 - val_loss: 0.0781
# Epoch 97/200
#  - 1s - loss: 0.0805 - val_loss: 0.0788
# Epoch 98/200
#  - 1s - loss: 0.0805 - val_loss: 0.0778
# Epoch 99/200
#  - 1s - loss: 0.0806 - val_loss: 0.0776
# Epoch 100/200
#  - 1s - loss: 0.0805 - val_loss: 0.0780
# Epoch 101/200
#  - 1s - loss: 0.0806 - val_loss: 0.0782
# Epoch 102/200
#  - 1s - loss: 0.0805 - val_loss: 0.0776
# Epoch 103/200
#  - 1s - loss: 0.0805 - val_loss: 0.0787
# Epoch 104/200
#  - 1s - loss: 0.0804 - val_loss: 0.0778
# Epoch 105/200
#  - 1s - loss: 0.0807 - val_loss: 0.0776
# Epoch 106/200
#  - 1s - loss: 0.0806 - val_loss: 0.0778
# Epoch 107/200
#  - 1s - loss: 0.0804 - val_loss: 0.0776
# Epoch 108/200
#  - 1s - loss: 0.0805 - val_loss: 0.0778
# Epoch 109/200
#  - 1s - loss: 0.0804 - val_loss: 0.0789
# Epoch 110/200
#  - 1s - loss: 0.0806 - val_loss: 0.0779
# Epoch 111/200
#  - 1s - loss: 0.0805 - val_loss: 0.0778
# Epoch 112/200
#  - 1s - loss: 0.0805 - val_loss: 0.0780
# Epoch 113/200
#  - 1s - loss: 0.0804 - val_loss: 0.0781
# Epoch 114/200
#  - 1s - loss: 0.0804 - val_loss: 0.0795
# Epoch 115/200
#  - 1s - loss: 0.0804 - val_loss: 0.0776
# Epoch 116/200
#  - 1s - loss: 0.0805 - val_loss: 0.0776
# Epoch 117/200
#  - 1s - loss: 0.0804 - val_loss: 0.0781
# Epoch 118/200
#  - 1s - loss: 0.0804 - val_loss: 0.0781
# Epoch 119/200
#  - 1s - loss: 0.0805 - val_loss: 0.0786
# Epoch 120/200
#  - 1s - loss: 0.0804 - val_loss: 0.0805
# Epoch 121/200
#  - 1s - loss: 0.0805 - val_loss: 0.0781
# Epoch 122/200
#  - 1s - loss: 0.0806 - val_loss: 0.0776
# Epoch 123/200
#  - 1s - loss: 0.0804 - val_loss: 0.0777
# Epoch 124/200
#  - 1s - loss: 0.0805 - val_loss: 0.0776
# Epoch 125/200
#  - 1s - loss: 0.0804 - val_loss: 0.0783
# Epoch 126/200
#  - 1s - loss: 0.0804 - val_loss: 0.0790
# Epoch 127/200
#  - 1s - loss: 0.0805 - val_loss: 0.0799
# Epoch 128/200
#  - 1s - loss: 0.0806 - val_loss: 0.0780
# Epoch 129/200
#  - 1s - loss: 0.0805 - val_loss: 0.0809
# Epoch 130/200
#  - 1s - loss: 0.0805 - val_loss: 0.0778
# Epoch 131/200
#  - 1s - loss: 0.0805 - val_loss: 0.0778
# Epoch 132/200
#  - 1s - loss: 0.0804 - val_loss: 0.0786
# Epoch 133/200
#  - 1s - loss: 0.0805 - val_loss: 0.0782
# Epoch 134/200
#  - 1s - loss: 0.0807 - val_loss: 0.0778
# Epoch 135/200
#  - 1s - loss: 0.0805 - val_loss: 0.0779
# Minimum validation loss of 0.07756674833714015 reached at epoch 104

# %%
preds = []
preds_array = stacked_lstm.predict(test_X)
for i in range(len(preds_array)):
    preds.append(preds_array[i][0])

train_data = pd.DataFrame({
    'Ozone Concentration':train_y,
    'Date':df.index[7:3107]
})
train_data['Observation Type'] = 'Actual'

val_data = pd.DataFrame({
    'Ozone Concentration':val_y,
    'Date':df.index[3107:-361]
})
val_data['Observation Type'] = 'Actual'

test_data = pd.DataFrame({
    'Ozone Concentration':preds,
    'Date':df.index[-360:]
})
test_data['Observation Type'] = 'Predicted'

plot_me = pd.concat([train_data,val_data,test_data])

sns.lineplot(x=plot_me.Date,y=plot_me['Ozone Concentration'],hue=plot_me['Observation Type'])

# %%
sns.lineplot(x=df.index,y=df['Daily Max 8-hour Ozone Concentration'])
